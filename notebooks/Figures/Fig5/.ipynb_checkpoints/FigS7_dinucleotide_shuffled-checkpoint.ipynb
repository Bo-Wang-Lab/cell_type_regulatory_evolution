# %% [markdown]
# ## Heatmap for Schisto peaks Smed models

# %%
schisto_neural_filtered = pd.read_csv("./across_species/schisto_peaks_profile_SHAP/neural_peaks_withallinfo_filtered.csv", sep="\t")
schisto_muscle_filtered = pd.read_csv("./across_species/schisto_peaks_profile_SHAP/muscle_peaks_withallinfo_filtered.csv", sep="\t")
schisto_intestine_filtered = pd.read_csv("./across_species/schisto_peaks_profile_SHAP/intestine_peaks_withallinfo_filtered.csv", sep="\t")
schisto_epidermal_filtered = pd.read_csv("./across_species/schisto_peaks_profile_SHAP/epidermal_peaks_withallinfo_filtered.csv", sep="\t")
schisto_cathepsin_filtered = pd.read_csv("./across_species/schisto_peaks_profile_SHAP/cathepsin_peaks_withallinfo_filtered.csv", sep="\t")

# %%
Sman_neural_all = pd.read_csv("./across_species_shuffled/Sman_peaks_profile_SHAP/Sman_neural_peaks_withallinfo_filtered.csv", sep="\t")
Sman_muscle_all = pd.read_csv("./across_species_shuffled/Sman_peaks_profile_SHAP/Sman_muscle_peaks_withallinfo_filtered.csv", sep="\t")
Sman_intestine_all = pd.read_csv("./across_species_shuffled/Sman_peaks_profile_SHAP/Sman_intestine_peaks_withallinfo_filtered.csv", sep="\t")
Sman_epidermal_all = pd.read_csv("./across_species_shuffled/Sman_peaks_profile_SHAP/Sman_tegument_peaks_withallinfo_filtered.csv", sep="\t")
Sman_cathepsin_all = pd.read_csv("./across_species_shuffled/Sman_peaks_profile_SHAP/Sman_cathepsin_peaks_withallinfo_filtered.csv", sep="\t")

# %%
Sman_neural_median = Sman_neural_all.iloc[:,[0,1,2,3,4]].median()
Sman_muscle_median = Sman_muscle_all.iloc[:,[0,1,2,3,4]].median()
Sman_intestine_median = Sman_intestine_all.iloc[:,[0,1,2,3,4]].median()
Sman_epidermal_median = Sman_epidermal_all.iloc[:,[0,1,2,3,4]].median()
Sman_cathepsin_median = Sman_cathepsin_all.iloc[:,[0,1,2,3,4]].median()

Sman_neural_SHAP_median = Sman_neural_all.iloc[:,[5,6,7,8,9]].median()
Sman_muscle_SHAP_median = Sman_muscle_all.iloc[:,[5,6,7,8,9]].median()
Sman_intestine_SHAP_median = Sman_intestine_all.iloc[:,[5,6,7,8,9]].median()
Sman_epidermal_SHAP_median = Sman_epidermal_all.iloc[:,[5,6,7,8,9]].median()
Sman_cathepsin_SHAP_median = Sman_cathepsin_all.iloc[:,[5,6,7,8,9]].median()


schisto_neural_median = schisto_neural_filtered.iloc[:,[0,1,2,3,4]].median()
schisto_muscle_median = schisto_muscle_filtered.iloc[:,[0,1,2,3,4]].median()
schisto_intestine_median = schisto_intestine_filtered.iloc[:,[0,1,2,3,4]].median()
schisto_epidermal_median = schisto_epidermal_filtered.iloc[:,[0,1,2,3,4]].median()
schisto_cathepsin_median = schisto_cathepsin_filtered.iloc[:,[0,1,2,3,4]].median()

Sman_neural_SHAP_median = Sman_neural_all.iloc[:,[5,6,7,8,9]].median()
Sman_muscle_SHAP_median = Sman_muscle_all.iloc[:,[5,6,7,8,9]].median()
Sman_intestine_SHAP_median = Sman_intestine_all.iloc[:,[5,6,7,8,9]].median()
Sman_epidermal_SHAP_median = Sman_epidermal_all.iloc[:,[5,6,7,8,9]].median()
Sman_cathepsin_SHAP_median = Sman_cathepsin_all.iloc[:,[5,6,7,8,9]].median()


schisto_neural_SHAP_median = schisto_neural_filtered.iloc[:,[6,7,8,9,10]].median()
schisto_muscle_SHAP_median = schisto_muscle_filtered.iloc[:,[6,7,8,9,10]].median()
schisto_intestine_SHAP_median = schisto_intestine_filtered.iloc[:,[6,7,8,9,10]].median()
schisto_epidermal_SHAP_median = schisto_epidermal_filtered.iloc[:,[6,7,8,9,10]].median()
schisto_cathepsin_SHAP_median = schisto_cathepsin_filtered.iloc[:,[6,7,8,9,10]].median()

# %%
schisto_profile = pd.DataFrame([schisto_neural_median, schisto_muscle_median, schisto_intestine_median, schisto_cathepsin_median, schisto_epidermal_median])
Sman_profile = pd.DataFrame([Sman_neural_median, Sman_muscle_median,Sman_intestine_median, Sman_cathepsin_median,Sman_epidermal_median ])
profile_combined = pd.concat([schisto_profile,Sman_profile],axis=1)

schisto_profile_SHAP = pd.DataFrame([schisto_neural_SHAP_median, schisto_muscle_SHAP_median, schisto_intestine_SHAP_median, schisto_cathepsin_SHAP_median, schisto_epidermal_SHAP_median])
Sman_profile_SHAP = pd.DataFrame([Sman_neural_SHAP_median, Sman_muscle_SHAP_median, Sman_intestine_SHAP_median, Sman_cathepsin_SHAP_median, Sman_epidermal_SHAP_median])
SHAP_combined = pd.concat([schisto_profile_SHAP,Sman_profile_SHAP],axis=1)

# %%
Sman_profile_normalized = min_max_normalize_rows(profile_combined)
Sman_profile_normalized.columns = [['corr_neural','corr_muscle','corr_intestine','corr_cathepsin','corr_epidermal',
                                    'corr_neural_shuf','corr_muscle_shuf','corr_intestine_shuf','corr_cathepsin_shuf','corr_epidermal_shuf']]
Sman_profile_normalized.index = ['neural','muscle','intestine','cathepsin','epidermal']

Sman_profile_SHAP_normalized = min_max_normalize_rows(SHAP_combined)
Sman_profile_SHAP_normalized.columns = [['corr_neural','corr_muscle','corr_intestine','corr_cathepsin','corr_epidermal',
                                    'corr_neural_shuf','corr_muscle_shuf','corr_intestine_shuf','corr_cathepsin_shuf','corr_epidermal_shuf']]
Sman_profile_SHAP_normalized.index = ['neural','muscle','intestine','cathepsin','epidermal']

# %%
import matplotlib.pyplot as plt

custom_cmap = matplotlib.colors.LinearSegmentedColormap.from_list( 'custom',plt.get_cmap('Reds')(np.linspace(0,1,100)**(2)) )

sns.heatmap(Sman_profile_normalized, annot=False,cmap=custom_cmap)
plt.title("schisto_peaks profile")
plt.savefig("./Figures/Figure6/schisto_profile_heatmap_normalized_shuffled.svg",format="svg")

# %% [markdown]
# ### Heatmap for Smed peaks schisto models

# %%
Smed_neural_filtered = pd.read_csv("./across_species/Smed_peaks_profile_SHAP/neural_peaks_withallinfo_filtered.csv", sep="\t")
Smed_muscle_filtered = pd.read_csv("./across_species/Smed_peaks_profile_SHAP/muscle_peaks_withallinfo_filtered.csv", sep="\t")
Smed_intestine_filtered = pd.read_csv("./across_species/Smed_peaks_profile_SHAP/intestine_peaks_withallinfo_filtered.csv", sep="\t")
Smed_epidermal_filtered = pd.read_csv("./across_species/Smed_peaks_profile_SHAP/epidermal_peaks_withallinfo_filtered.csv", sep="\t")
Smed_cathepsin_filtered = pd.read_csv("./across_species/Smed_peaks_profile_SHAP/cathepsin_peaks_withallinfo_filtered.csv", sep="\t")

# %%
Smed_neural_all = pd.read_csv("./across_species_shuffled/Smed_peaks_profile_SHAP/Smed_neural_peaks_withallinfo_filtered.csv", sep="\t")
Smed_muscle_all = pd.read_csv("./across_species_shuffled/Smed_peaks_profile_SHAP/Smed_muscle_peaks_withallinfo_filtered.csv", sep="\t")
Smed_intestine_all = pd.read_csv("./across_species_shuffled/Smed_peaks_profile_SHAP/Smed_intestine_peaks_withallinfo_filtered.csv", sep="\t")
Smed_epidermal_all = pd.read_csv("./across_species_shuffled/Smed_peaks_profile_SHAP/Smed_epidermal_peaks_withallinfo_filtered.csv", sep="\t")
Smed_cathepsin_all = pd.read_csv("./across_species_shuffled/Smed_peaks_profile_SHAP/Smed_cathepsin_peaks_withallinfo_filtered.csv", sep="\t")

# %%
Smed_epidermal_all = Smed_epidermal_all.rename(columns={"corr_epidermal.1": "corr_epidermal_SHAP"})
Smed_epidermal_filtered = Smed_epidermal_filtered.rename(columns={"corr_epidermal_SHAP": "corr_epidermal"})
Smed_epidermal_filtered = Smed_epidermal_filtered.rename(columns={"corr_epidermal_SHAP.1": "corr_epidermal_SHAP"})
Smed_neural_filtered = Smed_neural_filtered.rename(columns={"corr_epidermal_SHAP": "corr_epidermal"})
Smed_neural_filtered = Smed_neural_filtered.rename(columns={"corr_epidermal_SHAP.1": "corr_epidermal_SHAP"})
Smed_muscle_filtered = Smed_muscle_filtered.rename(columns={"corr_epidermal_SHAP": "corr_epidermal"})
Smed_muscle_filtered = Smed_muscle_filtered.rename(columns={"corr_epidermal_SHAP.1": "corr_epidermal_SHAP"})
Smed_intestine_filtered = Smed_intestine_filtered.rename(columns={"corr_epidermal_SHAP": "corr_epidermal"})
Smed_intestine_filtered = Smed_intestine_filtered.rename(columns={"corr_epidermal_SHAP.1": "corr_epidermal_SHAP"})
Smed_cathepsin_filtered = Smed_cathepsin_filtered.rename(columns={"corr_epidermal_SHAP": "corr_epidermal"})
Smed_cathepsin_filtered = Smed_cathepsin_filtered.rename(columns={"corr_epidermal_SHAP.1": "corr_epidermal_SHAP"})

# %%
# shuf 
Smed_neural_median_shuf = Smed_neural_all.iloc[:,[0,1,2,3,4]].median()
Smed_muscle_median_shuf = Smed_muscle_all.iloc[:,[0,1,2,3,4]].median()
Smed_intestine_median_shuf = Smed_intestine_all.iloc[:,[0,1,2,3,4]].median()
Smed_epidermal_median_shuf = Smed_epidermal_all.iloc[:,[0,1,2,3,4]].median()
Smed_cathepsin_median_shuf = Smed_cathepsin_all.iloc[:,[0,1,2,3,4]].median()

Smed_neural_SHAP_median_shuf = Smed_neural_all.iloc[:,[5,6,7,8,9]].median()
Smed_muscle_SHAP_median_shuf = Smed_muscle_all.iloc[:,[5,6,7,8,9]].median()
Smed_intestine_SHAP_median_shuf = Smed_intestine_all.iloc[:,[5,6,7,8,9]].median()
Smed_epidermal_SHAP_median_shuf = Smed_epidermal_all.iloc[:,[5,6,7,8,9]].median()
Smed_cathepsin_SHAP_median_shuf = Smed_cathepsin_all.iloc[:,[5,6,7,8,9]].median()

# unshuffled 
Smed_neural_median = Smed_neural_filtered.iloc[:,[0,1,2,3,4]].median()
Smed_muscle_median = Smed_muscle_filtered.iloc[:,[0,1,2,3,4]].median()
Smed_intestine_median = Smed_intestine_filtered.iloc[:,[0,1,2,3,4]].median()
Smed_epidermal_median = Smed_epidermal_filtered.iloc[:,[0,1,2,3,4]].median()
Smed_cathepsin_median = Smed_cathepsin_filtered.iloc[:,[0,1,2,3,4]].median()

Smed_neural_SHAP_median = Smed_neural_filtered.iloc[:,[5,6,7,8,9]].median()
Smed_muscle_SHAP_median = Smed_muscle_filtered.iloc[:,[5,6,7,8,9]].median()
Smed_intestine_SHAP_median = Smed_intestine_filtered.iloc[:,[5,6,7,8,9]].median()
Smed_epidermal_SHAP_median = Smed_epidermal_filtered.iloc[:,[5,6,7,8,9]].median()
Smed_cathepsin_SHAP_median = Smed_cathepsin_filtered.iloc[:,[5,6,7,8,9]].median()

# %%
Smed_profile = pd.DataFrame([Smed_neural_median, Smed_muscle_median, Smed_intestine_median, Smed_cathepsin_median, Smed_epidermal_median])
Smed_profile_shuf = pd.DataFrame([Smed_neural_median_shuf, Smed_muscle_median_shuf, Smed_intestine_median_shuf, Smed_cathepsin_median_shuf, Smed_epidermal_median_shuf ])
profile_combined = pd.concat([Smed_profile,Smed_profile_shuf],axis=1)

Smed_SHAP = pd.DataFrame([Smed_neural_SHAP_median, Smed_muscle_SHAP_median, Smed_intestine_SHAP_median, Smed_cathepsin_SHAP_median, Smed_epidermal_SHAP_median])
Smed_SHAP_shuf = pd.DataFrame([Smed_neural_SHAP_median_shuf, Smed_muscle_SHAP_median_shuf, Smed_intestine_SHAP_median_shuf, Smed_cathepsin_SHAP_median_shuf, Smed_epidermal_SHAP_median_shuf ])
SHAP_combined = pd.concat([Smed_SHAP,Smed_SHAP_shuf],axis=1)

# %%
Smed_profile_normalized = min_max_normalize_rows(profile_combined)
Smed_profile_normalized.columns = [['corr_neural','corr_muscle','corr_intestine','corr_cathepsin','corr_epidermal',
                                    'corr_neural_shuf','corr_muscle_shuf','corr_intestine_shuf','corr_cathepsin_shuf','corr_epidermal_shuf']]
Smed_profile_normalized.index = ['neural','muscle','intestine','cathepsin','epidermal']

Smed_SHAP_normalized = min_max_normalize_rows(SHAP_combined)
Smed_SHAP_normalized.columns = [['corr_neural','corr_muscle','corr_intestine','corr_cathepsin','corr_epidermal',
                                    'corr_neural_shuf','corr_muscle_shuf','corr_intestine_shuf','corr_cathepsin_shuf','corr_epidermal_shuf']]
Smed_SHAP_normalized.index = ['neural','muscle','intestine','cathepsin','epidermal']

# %%
custom_cmap = matplotlib.colors.LinearSegmentedColormap.from_list( 'custom',plt.get_cmap('Reds')(np.linspace(0,1,100)**(2)) )

sns.heatmap(Smed_profile_normalized, annot=False,cmap=custom_cmap)
plt.title("Smed_peaks profile")
plt.savefig("./Figures/Figure6/schisto_model_Smedpeaks_profile_heatmap_normalized_shuffled.svg",format="svg")
